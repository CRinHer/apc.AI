# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load data from CSV
data_title = 'output.csv'
data = pd.read_csv(data_title)

# %%
column_title = 'System_1_MV_3_3'
column_data = data[column_title]
# mv = '4'
# system = '2'
# column_title_1 = 'System_' + system + '_MV_' + mv + '_1'
# column_data_1 = data[column_title_1]
# column_title_2 = 'System_' + system + '_MV_' + mv + '_2'
# column_data_2 = data[column_title_2]
# column_title_3 = 'System_' + system + '_MV_' + mv + '_3'
# column_data_3 = data[column_title_3]
# column_title_4 = 'System_' + system + '_MV_' + mv + '_4'
# column_data_4 = data[column_title_4]

# %%
# Plotting the selected column
plt.figure(figsize = (2,2), dpi = 100)
plt.plot(column_data)
plt.axis('off')
plt.show()

# %%
# Plotting the selected column
# plt.figure(figsize = (2,2), dpi = 100)
plt.plot(column_data)
plt.title('Plot of ' + column_title)
plt.xlabel('Time')
plt.ylabel('Values of ' + column_title)
plt.show()

# %%
# plt.plot(column_data_1)
# plt.plot(column_data_2)
# plt.plot(column_data_3)
# plt.plot(column_data_4)
# plt.axis('off')
# plt.show()
# plt.figure(figsize = (2,2), dpi = 100)
# plt.plot(column_data_1)
# plt.plot(column_data_2)
# plt.plot(column_data_3)
# plt.plot(column_data_4)
# plt.axis('off')
# plt.show()
